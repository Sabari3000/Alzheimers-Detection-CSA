# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
import cv2  # OpenCV for image processing
import os
import random
import time
import joblib

# %%
class CrowSearchAlgorithm:
    def __init__(self, num_crows, max_iter, search_space, awareness=0.1, flight_length=2):
        self.num_crows = num_crows
        self.max_iter = max_iter
        self.search_space = search_space
        self.awareness = awareness
        self.flight_length = flight_length

    def fitness(self, params, X_train, y_train, X_val, y_val):
        # Train model with given parameters
        model = RandomForestClassifier(n_estimators=int(params[0]), max_depth=int(params[1]), random_state=42)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)
        accuracy = accuracy_score(y_val, y_pred)
        print(f"Current params: {params}, Validation accuracy: {accuracy:.4f}")
        return accuracy

    def optimize(self, X_train, y_train, X_val, y_val):
        print("Starting Crow Search Optimization...")
        crows_position = np.random.uniform(self.search_space[0], self.search_space[1], 
                                           (self.num_crows, len(self.search_space[0])))
        memory = crows_position.copy()
        best_solution = crows_position[0]
        best_fitness = self.fitness(best_solution, X_train, y_train, X_val, y_val)

        for t in range(self.max_iter):
            print(f"Iteration {t+1}/{self.max_iter}")
            for i in range(self.num_crows):
                if random.random() > self.awareness:
                    random_crow = random.randint(0, self.num_crows - 1)
                    crows_position[i] = crows_position[i] + self.flight_length * (memory[random_crow] - crows_position[i])
                    crows_position[i] = np.clip(crows_position[i], self.search_space[0], self.search_space[1])
                else:
                    crows_position[i] = np.random.uniform(self.search_space[0], self.search_space[1])

                current_fitness = self.fitness(crows_position[i], X_train, y_train, X_val, y_val)
                if current_fitness > self.fitness(memory[i], X_train, y_train, X_val, y_val):
                    memory[i] = crows_position[i]
                    if current_fitness > best_fitness:
                        best_fitness = current_fitness
                        best_solution = crows_position[i]

            print(f"Best solution so far: {best_solution}, Fitness: {best_fitness:.4f}")

        print("Optimization complete!")
        return best_solution, best_fitness

# %%
def load_and_preprocess_images(image_folder, target_size=(128, 128)):
    data = []
    labels = []
    label_map = {
        'Non Demented': 0,
        'Very mild Dementia': 1,
        'Mild Dementia': 2,
        'Moderate Dementia': 3
    }

    print("Loading and preprocessing images...")
    start_time = time.time()
    for label in label_map.keys():
        folder_path = os.path.join(image_folder, label)
        print(f"Processing images for class: {label}")
        iter=0
        for filename in os.listdir(folder_path):
            iter+=1
            if iter>500:
                continue
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, target_size)
            data.append(img.flatten())
            labels.append(label_map[label])
    print(f"Image loading and preprocessing completed in {time.time() - start_time:.2f} seconds.")
    return np.array(data), np.array(labels)

# %%
# Load MRI data
X, y = load_and_preprocess_images('./Train/')

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Define the CSA optimization search space for RandomForest parameters
search_space = [np.array([10, 5]), np.array([100, 20])]

# Initialize CSA
csa = CrowSearchAlgorithm(num_crows=5, max_iter=20, search_space=search_space)

# Optimize parameters using CSA
print("Optimizing model parameters with CSA...")
best_solution, best_fitness = csa.optimize(X_train, y_train, X_val, y_val)

print("Best Solution:", best_solution)
print("Best Fitness:", best_fitness)

# Train final model with best parameters from CSA
print("Training the final model with optimized parameters...")
final_model = RandomForestClassifier(n_estimators=int(best_solution[0]), max_depth=int(best_solution[1]), random_state=42)
final_model.fit(X_train, y_train)


# Evaluate on test data
print("Evaluating model on test data...")
y_pred = final_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Loading and preprocessing images...
# Processing images for class: Non Demented
# Processing images for class: Very mild Dementia
# Processing images for class: Mild Dementia
# Processing images for class: Moderate Dementia
# Image loading and preprocessing completed in 2.31 seconds.
# Optimizing model parameters with CSA...
# Starting Crow Search Optimization...
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Iteration 1/20
# Current params: [87.73142607  8.08703061], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [18.11980346  5.80071738], Validation accuracy: 0.9964
# Current params: [18.11980346  5.80071738], Validation accuracy: 0.9964
# Current params: [49.0677242 20.       ], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [94.16301721 10.83429161], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [87.73142607  8.08703061], Fitness: 1.0000
# Iteration 2/20
# Current params: [93.82257698  9.60638182], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [18.11980346  5.80071738], Validation accuracy: 0.9964
# Current params: [81.47082494 15.76384909], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [32.18062043 11.88649594], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [86.44129955 17.96035709], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [93.82257698  9.60638182], Fitness: 1.0000
# Iteration 3/20
# Current params: [69.11907289 20.        ], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [30.53854913 15.76384909], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [71.5298757  10.20510606], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [100.          19.05833872], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [69.11907289 20.        ], Fitness: 1.0000
# Iteration 4/20
# Current params: [61.41947624 15.76384909], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [100.          15.18098557], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [98.20756349 10.18193936], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [47.73493354  5.        ], Validation accuracy: 0.9964
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [53.00070064  5.96895516], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [61.41947624 15.76384909], Fitness: 1.0000
# Iteration 5/20
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [62.94164987 15.76384909], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [100.  20.], Fitness: 1.0000
# Iteration 6/20
# Current params: [53.00070064  5.96895516], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [67.59689926 20.        ], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [62.94164987 10.94483466], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [30.53854913 15.76384909], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [47.73493354  5.        ], Validation accuracy: 0.9964
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [53.00070064  5.96895516], Fitness: 1.0000
# Iteration 7/20
# Current params: [94.73423289 11.34582249], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [85.40380138  5.96895516], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [84.79328366  6.36994298], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [100.   5.], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.          12.31477765], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [94.73423289 11.34582249], Fitness: 1.0000
# Iteration 8/20
# Current params: [35.80431624 20.        ], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [67.59689926 20.        ], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [45.74526547 20.        ], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [47.73493354 12.31477765], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [62.94164987 18.63005702], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [35.80431624 20.        ], Fitness: 1.0000
# Iteration 9/20
# Current params: [94.73423289 15.76384909], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [62.94164987 15.76384909], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [56.03093724 18.01851485], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [94.73423289 15.76384909], Fitness: 1.0000
# Iteration 10/20
# Current params: [53.00070064  5.        ], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [44.32139201 18.71211207], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [91.70399629  5.        ], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [47.73493354  5.        ], Validation accuracy: 0.9964
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [53.00070064  5.96895516], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [53.00070064  5.        ], Fitness: 1.0000
# Iteration 11/20
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [100.   5.], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [38.83455284 20.        ], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [82.8036156 20.       ], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [100.  20.], Fitness: 1.0000
# Iteration 12/20
# Current params: [62.94164987 10.94483466], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [83.85844451 15.55909726], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [91.70399629 15.76384909], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [80.13803427 10.94483466], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [62.94164987 10.94483466], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [62.94164987 10.94483466], Fitness: 1.0000
# Iteration 13/20
# Current params: [90.05905077 15.02412049], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [69.14225613 10.40985789], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [61.29670435 10.20510606], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [50.40051486 20.        ], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [90.05905077 15.02412049], Fitness: 1.0000
# Iteration 14/20
# Current params: [40.47949836 20.        ], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [83.85844451 15.55909726], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [100.          10.94483466], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [40.47949836 20.        ], Fitness: 1.0000
# Iteration 15/20
# Current params: [100.          10.94483466], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [63.87648903  5.        ], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [28.72351819 16.81129815], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [30.53854913 20.        ], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [100.          10.94483466], Fitness: 1.0000
# Iteration 16/20
# Current params: [62.94164987 20.        ], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [89.12421161 20.        ], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [100.          18.95255094], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [100.           5.96895516], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [62.94164987 20.        ], Fitness: 1.0000
# Iteration 17/20
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [64.11491977 19.76851984], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [62.94164987 20.        ], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [53.00070064  5.96895516], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [100.  20.], Fitness: 1.0000
# Iteration 18/20
# Current params: [62.94164987 10.94483466], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [83.62001377  5.        ], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [30.53854913 15.76384909], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [62.94164987 10.94483466], Fitness: 1.0000
# Iteration 19/20
# Current params: [67.59689926 20.        ], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [69.38068687 20.        ], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [100.          15.18098557], Validation accuracy: 1.0000
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [62.94164987 10.94483466], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [47.73493354  5.        ], Validation accuracy: 0.9964
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [67.59689926 20.        ], Fitness: 1.0000
# Iteration 20/20
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [65.26927457 17.88192455], Validation accuracy: 1.0000
# Current params: [71.54979351  9.99521796], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [47.73493354  5.        ], Validation accuracy: 0.9964
# Current params: [81.47082494 15.47241733], Validation accuracy: 1.0000
# Current params: [67.59689926 20.        ], Validation accuracy: 1.0000
# Current params: [73.86746677  8.65738882], Validation accuracy: 1.0000
# Current params: [100.  20.], Validation accuracy: 1.0000
# Current params: [76.50035032 12.98447758], Validation accuracy: 1.0000
# Best solution so far: [100.  20.], Fitness: 1.0000
# Optimization complete!
# Best Solution: [100.  20.]
# Best Fitness: 1.0
# Training the final model with optimized parameters...
# Evaluating model on test data...
# Test Accuracy: 0.9983

# %%
# Save the trained model and scaler
model_path = "final_model.pkl"
scaler_path = "scaler.pkl"

print("Saving the model and scaler...")
joblib.dump(final_model, model_path)
joblib.dump(scaler, scaler_path)
print(f"Model saved to {model_path} and scaler saved to {scaler_path}")
# Out:
# Saving the model and scaler...
# Model saved to final_model.pkl and scaler saved to scaler.pkl

# %%
def predict_dementia_risk(image_path, model, scaler):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (128, 128))
    img = img.flatten()
    img = scaler.transform([img])

    prob = model.predict_proba(img)[0]  # Probability for each class
    class_labels = ["Non Demented", "Very mild Dementia", "Mild Dementia", "Moderate Dementia"]
    most_likely_class = class_labels[np.argmax(prob)]
    likelihood = np.max(prob) * 100

    print(f"Class probabilities: {dict(zip(class_labels, prob * 100))}")
    return most_likely_class, likelihood

# Example usage
image_path = './New Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_152.jpg'
most_likely_class, likelihood = predict_dementia_risk(image_path, final_model, scaler)
print(f"The most likely class is '{most_likely_class}' with a probability of {likelihood:.2f}%")
# Out:
# Class probabilities: {'Non Demented': np.float64(24.0), 'Very mild Dementia': np.float64(35.0), 'Mild Dementia': np.float64(21.0), 'Moderate Dementia': np.float64(20.0)}
# The most likely class is 'Very mild Dementia' with a probability of 35.00%
